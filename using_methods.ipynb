# %% [markdown]
# ## Applying the transformations

# %% [markdown]
# #### This jupyter contains the applications of the methods created in the classes of the proj_oo_etl

# %%
import pandas as pd

from Connection import Connection
from Extract import Extract
from Transform import Transform
from Load import Load

# %%
# Creating an instance of the connection object
instance_con = Connection()
datalake = instance_con.mysql_con('datalake')
dw = instance_con.mysql_con('data_warehouse')
# Out:
# Instance of connection object
#
# Database: datalake
# User: welbert
#
# Database: data_warehouse
# User: welbert

# %%
# Creating an instance of the extract object
instance_extract = Extract()
# Out:
# Instance of extract object

# %%
# Creating a dataframe using a local csv
economic_freedom = instance_extract.create_df_using_csv(
    csv_path_and_file_name\
         = '/home/welbert/Documents/proj_oo/exported_datasets/economic_freedom_test_file.csv',
         separator = ';'
    )
# Out:
# Used encoding: utf-8
# /tmp/ipykernel_3847671/65578968.py:2: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   economic_freedom = instance_extract.create_df_using_csv(

# %%
# creating df before transformation
teste = economic_freedom[
        ["Population (Millions)", 
        "GDP (Billions, PPP)", 
        "GDP per Capita (PPP)", 
        "Unemployment (%)", 
        "FDI Inflow (Millions)"]]

# %%
# Printing Information before apply the transformation in the teste df
print(teste.info())
teste.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Population (Millions)  186 non-null    object
#  1   GDP (Billions, PPP)    185 non-null    object
#  2   GDP per Capita (PPP)   184 non-null    object
#  3   Unemployment (%)       181 non-null    object
#  4   FDI Inflow (Millions)  181 non-null    object
# dtypes: object(5)
# memory usage: 7.4+ KB
# None
#   Population (Millions) GDP (Billions, PPP) GDP per Capita (PPP)  \
# 0                  35.5              $69.6                $1,958
# 1                   2.9              $36.0               $12,507
# 2                  41.5             $632.9               $15,237
# 3                  28.2             $190.3                $6,753
# 4                  44.1             $920.2               $20,876
#
#   Unemployment (%) FDI Inflow (Millions)
# ...

# %%
# Creating an instance of transform object and transforming the float columns
t = Transform()

economic_freedom_transformed\
    = t.transform_columns_type(
        economic_freedom,
        [ 
            "GDP (Billions, PPP)", 
            "GDP per Capita (PPP)", 
            "Unemployment (%)", 
            "FDI Inflow (Millions)"
        ], 
        'float')

economic_freedom_transformed.head()
# Out:
# Instance of transform object
#
# Column: GDP (Billions, PPP) transformed in float type.
# Column: GDP per Capita (PPP) transformed in float type.
# Column: Unemployment (%) transformed in float type.
# Column: FDI Inflow (Millions) transformed in float type.
#    CountryID Country Name      WEBNAME                        Region  \
# 0          1  Afghanistan  Afghanistan                  Asia-Pacific
# 1          2      Albania      Albania                        Europe
# 2          3      Algeria      Algeria  Middle East and North Africa
# 3          4       Angola       Angola            Sub-Saharan Africa
# 4          5    Argentina    Argentina                      Americas
#
#    World Rank  Region Rank  2019 Score  Property Rights  \
# 0       152.0         39.0        51.5             19.6
# 1        52.0         27.0        66.5             54.8
# 2       171.0         14.0        46.2             31.6
# 3       156.0         33.0        50.6             35.9
# ...

# %%
# creating and printing df after transformation
teste\
     = economic_freedom_transformed[
        ["Population (Millions)", 
        "GDP (Billions, PPP)", 
        "GDP per Capita (PPP)", 
        "Unemployment (%)", 
        "FDI Inflow (Millions)"
        ]
    ]
teste.head()
# Out:
#   Population (Millions)  GDP (Billions, PPP)  GDP per Capita (PPP)  \
# 0                  35.5                 69.0                   1.0
# 1                   2.9                 36.0                  12.0
# 2                  41.5                632.0                  15.0
# 3                  28.2                190.0                   6.0
# 4                  44.1                920.0                  20.0
#
#    Unemployment (%)  FDI Inflow (Millions)
# 0               8.0                   53.0
# 1              13.0                    1.0
# 2              10.0                    1.0
# 3               8.0                    2.0
# 4               8.0                   11.0

# %%
# Printing Information after transformation
print(teste.info())
teste.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Population (Millions)  186 non-null    object
#  1   GDP (Billions, PPP)    185 non-null    float64
#  2   GDP per Capita (PPP)   184 non-null    float64
#  3   Unemployment (%)       181 non-null    float64
#  4   FDI Inflow (Millions)  181 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB
# None
#   Population (Millions)  GDP (Billions, PPP)  GDP per Capita (PPP)  \
# 0                  35.5                 69.0                   1.0
# 1                   2.9                 36.0                  12.0
# 2                  41.5                632.0                  15.0
# 3                  28.2                190.0                   6.0
# 4                  44.1                920.0                  20.0
#
# ...

# %%
# Grouping and printing data
mean_unemployment_region\
    = t.group_data(
        economic_freedom_transformed, 
        "Region", 
        "Unemployment (%)",
        "count")

mean_unemployment_region.head(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                               Unemployment (%)
# Region
# Sub-Saharan Africa                          47
# Europe                                      44
# Asia-Pacific                                41
# Americas                                    31
# Middle East and North Africa                18

# %%
# Filtering and printing df
data_filtered = t.filter_data(
    economic_freedom_transformed, 
    'Region', 
    'Europe'
    )

data_filtered.head()
# Out:
#     CountryID Country Name  WEBNAME  Region  World Rank  Region Rank  \
# 1           2      Albania  Albania  Europe        52.0         27.0
# 5           6      Armenia  Armenia  Europe        47.0         24.0
# 7           8      Austria  Austria  Europe        31.0         16.0
# 13         14      Belarus  Belarus  Europe       104.0         42.0
# 14         15      Belgium  Belgium  Europe        48.0         25.0
#
#     2019 Score  Property Rights  Judical Effectiveness  Government Integrity  \
# 1         66.5             54.8                   30.6                  40.4
# 5         67.7             57.2                   46.3                  38.6
# 7         72.0             84.2                   71.3                  77.4
# 13        57.9             55.2                   51.7                  37.7
# 14        67.3             81.3                   61.6                  72.5
#
#     ...  Country  Population (Millions)  GDP (Billions, PPP)  \
# ...

# %%
# Total lines in a dataframe
total_rows_Europe = t.df_total_rows(data_filtered)
print(total_rows_Europe)
# Out:
# Number of rows: 45

# %%
# Rows having nan in a specific column
with_nan = t.show_where_is_null(economic_freedom_transformed, "FDI Inflow (Millions)")
with_nan
# Out:
#      CountryID   Country Name        WEBNAME                        Region  \
# 42          42           Cuba           Cuba                      Americas
# 98          96          Libya          Libya  Middle East and North Africa
# 99          97  Liechtenstein  Liechtenstein                        Europe
# 113        111     Micronesia     Micronesia                  Asia-Pacific
# 161        159          Syria          Syria  Middle East and North Africa
#
#      World Rank  Region Rank  2019 Score  Property Rights  \
# 42        178.0         31.0        27.8             31.6
# 98          NaN          NaN         NaN              7.6
# 99          NaN          NaN         NaN              NaN
# 113       149.0         38.0        51.9              7.6
# 161         NaN          NaN         NaN             37.0
#
#      Judical Effectiveness  Government Integrity  ...        Country  \
# 42                    10.0                  37.7  ...           Cuba
# ...

# %%
# Deleting rows where the column have nan values
without_nan = t.delete_where_is_null(economic_freedom_transformed, "FDI Inflow (Millions)")

# %%
# Comparing the number of rows before/after delete nan 
print(f"Row number with nan: {economic_freedom_transformed.shape[0]}")
print(f"Row number without nan: {without_nan.shape[0]}")
# Out:
# Row number with nan: 186
# Row number without nan: 181

# %%
economic_freedom_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CountryID                    186 non-null    int64
#  1   Country Name                 186 non-null    object
#  2   WEBNAME                      186 non-null    object
#  3   Region                       186 non-null    object
#  4   World Rank                   180 non-null    float64
#  5   Region Rank                  180 non-null    float64
#  6   2019 Score                   180 non-null    float64
#  7   Property Rights              185 non-null    float64
#  8   Judical Effectiveness        185 non-null    float64
#  9   Government Integrity         185 non-null    float64
#  10  Tax Burden                   180 non-null    float64
#  11  Gov't Spending               183 non-null    float64
# ...

# %%
# Applying the method delete_where_is_null on all the columns of the princial df
economic_freedom_transformed = t.delete_where_is_null(
    economic_freedom_transformed
)

# %%
# Reshaping the df index
economic_freedom_transformed.index = range(economic_freedom_transformed.shape[0])
economic_freedom_transformed.index
# Out:
# RangeIndex(start=0, stop=173, step=1)

# %%
economic_freedom_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CountryID                    173 non-null    int64
#  1   Country Name                 173 non-null    object
#  2   WEBNAME                      173 non-null    object
#  3   Region                       173 non-null    object
#  4   World Rank                   173 non-null    float64
#  5   Region Rank                  173 non-null    float64
#  6   2019 Score                   173 non-null    float64
#  7   Property Rights              173 non-null    float64
#  8   Judical Effectiveness        173 non-null    float64
#  9   Government Integrity         173 non-null    float64
#  10  Tax Burden                   173 non-null    float64
#  11  Gov't Spending               173 non-null    float64
# ...

# %%
# Creating an instance of the Load class and applying the methods
l = Load()
l.load_data_frame_in_sql_db(
    df = economic_freedom, 
    target_conn = "datalake",
    type_connection = "mysql+pymysql",
    table_name = "economic_freedom"
)
# Out:
# Instance of load object
#
# Instance of connection object
#
# Engine(mysql+pymysql://welbert:***@localhost:3306/datalake)
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/engine/base.py:1900, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1899     if not evt_handled:
# -> 1900         self.dialect.do_execute(
#    1901             cursor, statement, parameters, context
#    1902         )
#    1904 if self._has_events or self.engine._has_events:
#
# File /usr/local/lib/python3.8/dist-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ...

# %%
import sqlalchemy as db

# %%
datalake = instance_con.sqlalchemy_conn(
    database_name = "datalake",
    type_connection = "mysql+pymysql"
)


dw = instance_con.sqlalchemy_conn(
    database_name = "data_warehouse",
    type_connection = "mysql+pymysql"
)

# %%
datalake
# Out:
# Engine(mysql+pymysql://welbert:***@localhost:3306/datalake)

# %%
metadata = db.MetaData()
cotacao_moedas = db.Table('cotacao_moedas', metadata, autoload = True, autoload_with = datalake)
print(cotacao_moedas.columns.keys())
# Out:
# ['code', 'codein', 'name', 'high', 'low', 'varBid', 'pctChange', 'bid', 'ask', 'timestamp', 'created_date']

# %%
query = db.select([cotacao_moedas])
query

# %%
result = datalake.execute(query)
result = result.fetchall()
result = pd.DataFrame(result)
result
# Out:
#    code codein                             name    high     low  varBid  \
# 0   USD    BRL  Dólar Americano/Real Brasileiro  5.2570  5.1462  0.0686
# 1   USD    BRL  Dólar Americano/Real Brasileiro  5.2422  5.1659 -0.0442
# 2   USD    BRL  Dólar Americano/Real Brasileiro  5.1901  5.1500 -0.0109
# 3   USD    BRL  Dólar Americano/Real Brasileiro  5.2504  5.1531  0.0960
# 4   USD    BRL  Dólar Americano/Real Brasileiro  5.2531  5.2484 -0.0043
# 5   USD    BRL  Dólar Americano/Real Brasileiro  5.2523  5.1815 -0.0241
# 6   USD    BRL  Dólar Americano/Real Brasileiro  5.2171  5.1385 -0.0546
# 7   USD    BRL  Dólar Americano/Real Brasileiro  5.1435  5.1430  0.0013
# 8   USD    BRL  Dólar Americano/Real Brasileiro  5.4066  5.2491 -0.0196
# 9   USD    BRL  Dólar Americano/Real Brasileiro  5.3519  5.2603 -0.0149
# 10  USD    BRL  Dólar Americano/Real Brasileiro  5.3333  5.3326  0.0008
# 11  USD    BRL  Dólar Americano/Real Brasileiro  5.3983  5.2891  0.0469
# ...
